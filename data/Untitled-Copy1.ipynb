# %%
avgThroughput_file1 = open("1/datafortest//MinThroughput.txt", "r")
avgThroughput1 = avgThroughput_file1.read().splitlines()
avgThroughput1 = [int(i) for i in avgThroughput1] 



maxThroughput_file1 = open("1/datafortest/MinThroughput.txt", "r")
maxThroughput1 = maxThroughput_file1.read().splitlines()
maxThroughput1 = [int(i) for i in maxThroughput1] 



minThroughput_file1 = open("1/datafortest/MinThroughput.txt", "r")
minThroughput1 = minThroughput_file1.read().splitlines()
minThroughput1 = [int(i) for i in minThroughput1] 



avgLatency_file1 = open("1/datafortest/AvgLatency.txt", "r")
avgLatency1 = avgLatency_file1.read().splitlines()
avgLatency1 = [float(i) for i in avgLatency1] 



maxLatency_file1 = open("1/datafortest/MaxLatency.txt", "r")
maxLatency1 = maxLatency_file1.read().splitlines()
maxLatency1 = [int(i) for i in maxLatency1] 

minLatency_file1 = open("1/datafortest/MinLatency.txt", "r")
minLatency1 = minLatency_file1.read().splitlines()
minLatency1 = [int(i) for i in minLatency1] 


nodeCount_file1 = open("1/datafortest/nodeCount.txt", "r")
nodeCount = nodeCount_file1.read().splitlines()
nodeCount = [int(i) for i in nodeCount] 


contentCount_file = open("1/datafortest/contentCount.txt", "r")
contentCount = contentCount_file.read().splitlines()
contentCount = [int(i) for i in contentCount]

testName_file = open("1/datafortest/testName.txt", "r")
testName = testName_file.read().splitlines()

# %%
avgThroughput_file2 = open("2/datafortest/AvgThroughput.txt", "r")
avgThroughput2 = avgThroughput_file2.read().splitlines()
avgThroughput2 = [int(i) for i in avgThroughput2] 


avgLatency_file2 = open("2/datafortest/AvgLatency.txt", "r")
avgLatency2 = avgLatency_file2.read().splitlines()
avgLatency2 = [float(i) for i in avgLatency2] 



maxLatency_file2 = open("2/datafortest/MaxLatency.txt", "r")
maxLatency2 = maxLatency_file2.read().splitlines()
maxLatency2 = [int(i) for i in maxLatency2] 

minLatency_file2 = open("2/datafortest/MinLatency.txt", "r")
minLatency2 = minLatency_file2.read().splitlines()
minLatency2 = [int(i) for i in minLatency2]

# %%
avgThroughput_file3 = open("3/datafortest/AvgThroughput.txt", "r")
avgThroughput3 = avgThroughput_file3.read().splitlines()
avgThroughput3 = [int(i) for i in avgThroughput3] 


avgLatency_file3 = open("3/datafortest/AvgLatency.txt", "r")
avgLatency3 = avgLatency_file3.read().splitlines()
avgLatency3 = [float(i) for i in avgLatency3] 



maxLatency_file3 = open("3/datafortest/MaxLatency.txt", "r")
maxLatency3 = maxLatency_file3.read().splitlines()
maxLatency3 = [int(i) for i in maxLatency3] 

minLatency_file3 = open("3/datafortest/MinLatency.txt", "r")
minLatency3 = minLatency_file3.read().splitlines()
minLatency3 = [int(i) for i in minLatency3]

# %%
print(avgThroughput1)
print(avgThroughput2)
print(avgThroughput3)
# Out:
# [100000, 418000, 287000, 395000, 870000, 507000, 921000, 625000, 490000, 900000, 1064000, 1064000]
# [153000, 414000, 265000, 468000, 683000, 834000, 581000, 340000, 461000, 513000, 730000, 780000]
# [129000, 703000, 324000, 432000, 371000, 1092000, 565000, 535000, 615000, 803000, 562000, 973000]

# %%
import numpy as np

avgThroughput =  (np.array(avgThroughput1)+ np.array(avgThroughput2)+np.array(avgThroughput3))/3

a = np.array([np.array(avgThroughput1),
       np.array(avgThroughput2),
      np.array(avgThroughput3)])

minThroughput = a.min(axis = 0)    #  Минимальный элемент каждой строки
maxThroughput = a.max(axis = 0)    #  Максимальный элемент каждого столбца

# %%
#import matplotlib libary
import matplotlib.pyplot as plt

#define plot size in inches (width, height) & resolution(DPI)
fig = plt.figure(figsize=(6, 3), dpi=100)

#define font size
plt.rc("font", size=14)

#define some data
x = contentCount
y = avgThroughput 

#error data
y_error1 = avgThroughput - minThroughput
y_error2 = maxThroughput -avgThroughput



#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

asymmetric_error = [y_error1, y_error2]


#plot only errorbars
#plt.errorbar(x, y, linestyle="None", marker="None", color="green")
plt.errorbar(x, y, yerr=asymmetric_error, linestyle="None", marker="None", color="green")


plt.ticklabel_format(useOffset=False, style='plain')



#configure  X axes
plt.xticks(fontsize=8)
plt.xlim(0,60)

#configure  Y axes
plt.ylim(10,1700000)
plt.yticks(fontsize=8)



#plt.yticks([20, 21, 20.5, 20.8])
plt.grid(True)


#labels
plt.ylabel("Throughput, шт/с ", size=8)
plt.xlabel ("Количество пакетов в системе, шт.", size=8)

#title
plt.title("Зависимость throughput от количества пакетов в системе Token Ring," + '\n' + "с передачей пакетов при помощи " + str(testName[0]) + '\n' + "при количестве узлов = " + str(nodeCount[0]) +'\n', size=10)


#adjust plot
plt.subplots_adjust(left=0.19)

#show plot
plt.savefig('figs/throughput/' + str(testName[0]) + str(nodeCount[0]) + 'node' + '.png', bbox_inches='tight',dpi=100)

plt.show()

# %%
avgLatency =  (np.array(avgLatency1)+ np.array(avgLatency2)+np.array(avgLatency3))/3

abs_a = np.array([np.array(avgLatency1),
       np.array(avgLatency2),
      np.array(avgLatency3)])

min_a = np.array([np.array(minLatency1),
       np.array(minLatency2),
      np.array(minLatency3)])

max_a = np.array([np.array(maxLatency1),
       np.array(maxLatency2),
      np.array(maxLatency3)])

minLatency = min_a.min(axis = 0)    #  Минимальный элемент каждой строки
maxLatency = max_a.max(axis = 0)    #  Максимальный элемент каждого столбца

abs_minLatency = abs_a.min(axis = 0)
abs_maxLatency = abs_a.max(axis = 0)

# %%
#import matplotlib libary
import matplotlib.pyplot as plt

#define plot size in inches (width, height) & resolution(DPI)
fig = plt.figure(figsize=(6, 3), dpi=100)

#define font size
plt.rc("font", size=14)

#define some data
x = contentCount
y = avgLatency

#error data
y_abs_error1 = avgLatency - abs_minLatency
y_abs_error2 = abs_maxLatency -avgLatency

y_error1 = avgLatency - minLatency
y_error2 = maxLatency -avgLatency


#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="red")

asymmetric_error = [y_error1, y_error2]
abs_asymmetric_error = [y_abs_error1, y_abs_error2]


print(asymmetric_error)


#plot only errorbars
plt.errorbar(x, y, yerr=asymmetric_error, linestyle="None", marker="None", color="black")


plt.errorbar(x, y, yerr=abs_asymmetric_error, linestyle="None", marker="None", color="red")







plt.ticklabel_format(useOffset=False, style='plain')



#configure  X axes
plt.xticks(fontsize=8)
plt.xlim(1,60)

#configure  Y axes
plt.ylim(0,16000)
plt.yticks(fontsize=8)



#plt.yticks([20, 21, 20.5, 20.8])
plt.grid(True)


#labels
plt.ylabel("Latency, с * 10^-9", size=8)
plt.xlabel ("Количество пакетов в системе, шт.", size=8)

#title
plt.title("Зависимость latency от количества пакетов в системе Token Ring," + '\n' + "с передачей пакетов при помощи " + str(testName[0]) + '\n' + "при количестве узлов = " + str(nodeCount[0]) +'\n', size=10)

#adjust plot
plt.subplots_adjust(left=0.19)

#show plot
plt.savefig('figs/latency/'+ str(testName[0]) + str(nodeCount[0]) + 'node' + '.png', bbox_inches='tight',dpi=100)


plt.show()
# Out:
# [array([ 193.33333333,  489.        ,  498.39393939,  377.08333333,
#        1753.47619048, 1567.42307692,  584.87096774, 2262.13888889,
#        3705.72357724, 2875.55797101, 1411.84313725, 1020.61904762]), array([ 236.66666667,  253.        ,  452.60606061,  411.91666667,
#        2687.52380952, 2215.57692308, 3077.12903226, 3748.86111111,
#        3243.27642276, 4706.44202899, 2072.15686275, 1400.38095238])]

# %%
#import matplotlib libary
import matplotlib.pyplot as plt

#define plot size in inches (width, height) & resolution(DPI)
fig = plt.figure(figsize=(6, 3), dpi=100)

#define font size
plt.rc("font", size=14)

#define some data
x = contentCount
y = avgThroughput 

#error data
y_error1 = minThroughput
y_error2 = maxThroughput



#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="green")

asymmetric_error = [y_error1, y_error2]


#plot only errorbars
plt.errorbar(x, y, yerr=asymmetric_error, linestyle="None", marker="None", color="green")

plt.ticklabel_format(useOffset=False, style='plain')



#configure  X axes
plt.xticks(fontsize=8)
plt.xlim(0,60)

#configure  Y axes
plt.ylim(0,75000)
plt.yticks(fontsize=8)



#plt.yticks([20, 21, 20.5, 20.8])
plt.grid(True)


#labels
plt.ylabel("Throughput, шт/с ", size=8)
plt.xlabel ("Количество пакетов в системе, шт.", size=8)

#title
plt.title("Зависимость throughput от количества пакетов в системе Token Ring," + '\n' + "с передачей пакетов при помощи " + str(testName[0]) + '\n' + "при количестве узлов = " + str(nodeCount[0]) +'\n', size=10)


#adjust plot
plt.subplots_adjust(left=0.19)

#show plot
plt.savefig('figs/throughput/'+ str(testName[0]) + str(nodeCount[0]) + 'node' + '.png', bbox_inches='tight',dpi=100)

plt.show()

# %%
#import matplotlib libary
import matplotlib.pyplot as plt

#define plot size in inches (width, height) & resolution(DPI)
fig = plt.figure(figsize=(6, 3), dpi=100)

#define font size
plt.rc("font", size=14)

#define some data
x = contentCount
y = avgLatency

#error data
y_error1 = minLatency
y_error2 = maxLatency



#plot data
plt.plot(x, y, linestyle="dashed", marker="o", color="red")

asymmetric_error = [y_error1, y_error2]
print(asymmetric_error)


#plot only errorbars
plt.errorbar(x, y, yerr=asymmetric_error, linestyle="None", marker="None", color="red")

plt.ticklabel_format(useOffset=False, style='plain')



#configure  X axes
plt.xticks(fontsize=8)
plt.xlim(1,60)

#configure  Y axes
plt.ylim(0,15000)
plt.yticks(fontsize=8)



#plt.yticks([20, 21, 20.5, 20.8])
plt.grid(True)


#labels
plt.ylabel("Latency, с * 10^-9", size=8)
plt.xlabel ("Количество пакетов в системе, шт.", size=8)

#title
plt.title("Зависимость latency от количества пакетов в системе Token Ring," + '\n' + "с передачей пакетов при помощи " + str(testName[0]) + '\n' + "при количестве узлов = " + str(nodeCount[0]) +'\n', size=10)

#adjust plot
plt.subplots_adjust(left=0.19)

#show plot
plt.savefig('figs/latency/'+ str(testName[0]) + str(nodeCount[0]) + 'node' + '.png', bbox_inches='tight',dpi=100)


plt.show()
# Out:
# [[387, 955, 1151, 1467, 1629, 2453, 4219, 5465, 4665, 6430, 7371, 6561], [387, 955, 3086, 3333, 1632, 2453, 4219, 5465, 4665, 6430, 7371, 7146]]
